# %% [markdown]
# Test wind data COASTGUARD

# %%
import numpy as np
import pandas as pd

# %%
wf = pd.read_csv(r'./data/wind_test_front.csv',header=None)
wl = pd.read_csv(r'./data/wind_test_left.csv',header=None)
# wr = pd.read_csv(r'./data/wind_test_right.csv')

# %%
fromfront = wf.dropna()
fromfront.columns =['a', 'b', 'u', 'v','w','c','d','e','f']
fromfront

fromleft = wl.dropna()
fromleft.columns =['a', 'b', 'u', 'v','w','c','d','e','f']
fromleft
# Out:
#                         a        b         u           v           w  c  \
# 0    data: "1517156375.07    \x02P  -002.149    -004.998    +000.369  M
# 2    data: "1517156375.17    \x02P  -000.619    -001.549    -001.428  M
# 4    data: "1517156375.27    \x02P  -001.658    -002.351    -001.391  M
# 6    data: "1517156375.37    \x02P  -002.518    -002.650    -001.502  M
# 8    data: "1517156375.47    \x02P  -000.546    -004.019    -000.653  M
# ..                    ...      ...       ...         ...         ... ..
# 810  data: "1517156415.57  \0\x02P  +000.086    -005.192    -001.364  M
# 812  data: "1517156415.67    \x02P  -000.944  -0\006.009    +000.760  M
# 814  data: "1517156415.77    \x02P  -000.799    -005.677  -002.37\07  M
# 816  data: "1517156415.87    \x02P  +000.428    -006.155    -000.359  M
# 818  data: "1517156415.97    \x02P  -001.652    -007.192    -001.523  M
#
#            d     e            f
# 0    +026.67    00  \x030A\r\n"
# 2    +026.72    00  \x030E\r\n"
# 4    +026.47    00  \x0305\r\n"
# 6    +026.67    00  \x030B\r\n"
# 8    +026.50    00  \x030D\r\n"
# ..       ...   ...          ...
# 810  +026.48    00  \x0308\r\n"
# 812  +026.98    00  \x0303\r\n"
# 814  +027.10    00  \x0306\r\n"
# 816  +026.76  00\0  \x0302\r\n"
# 818  +027.22    00  \x030A\r\n"
#
# [406 rows x 9 columns]

# %%
fromleft["u"] = pd.to_numeric(fromleft["u"], downcast="float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-002\0.875"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-13799e7dddd7> in <module>
# ----> 1 fromleft["u"] = pd.to_numeric(fromleft["u"], downcast="float")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-002\0.875" at position 96

# %%
fromleft[90:100]
# Out:
#                         a      b           u         v           w  c  \
# 180  data: "1517156384.07  \x02P    -000.383  -004.545    -001.477  M
# 182  data: "1517156384.17  \x02P    -002.673  -003.647    -002.007  M
# 184  data: "1517156384.27  \x02P    -002.357  -004.399    -000.807  M
# 186  data: "1517156384.37  \x02P    -003.713  -002.972    -002.257  M
# 188  data: "1517156384.47  \x02P    +000.134  -004.428    -001.050  M
# 190  data: "1517156384.57  \x02P    -002.506  -003.335    +000.289  M
# 192  data: "1517156384.67  \x02P  -002\0.875  -003.971    -000.956  M
# 194  data: "1517156384.77  \x02P    -002.305  -004.266  \0-001.084  M
# 196  data: "1517156384.87  \x02P    -001.319  -001.851    -001.709  M
# 198  data: "1517156384.97  \x02P    -002.380  -001.345    -000.447  M
#
#              d   e            f
# 180    +026.71  00  \x0308\r\n"
# 182    +026.72  00  \x0305\r\n"
# 184    +026.36  00  \x030D\r\n"
# 186    +026.52  00  \x030E\r\n"
# 188    +026.31  00  \x030F\r\n"
# 190    +026.66  00  \x0301\r\n"
# 192    +026.83  00  \x0306\r\n"
# 194    +026.48  00  \x0300\r\n"
# 196  +02\06.55  00  \x030B\r\n"
# 198    +026.59  00  \x0302\r\n"
